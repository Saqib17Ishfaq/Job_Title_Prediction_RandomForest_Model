# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings 
df = pd.read_csv('Job Prediction By Resume.csv')

# %%
df.head()
# Out:
#                Name  Gender Course in UG  \
# 0       A.Uha Priya  Female         B.Sc
# 1             Aadil    Male          B.E
# 2           Aakriti  Female           BA
# 3    Aanchal sharma  Female          MBA
# 4  Aangkeeta Sarkar  Female       B.Tech
#
#    UG specialization? Major Subject (Eg; Mathematics)  \
# 0                              Computer Applications
# 1                       Computer Science Engineering
# 2                                         Psychology
# 3                                           Commerce
# 4                        Instrumentation Engineering
#
#                                            Interests  \
# 0                                    Cloud computing
# 1                                         Technology
# 2                         Understand human behaviour
# 3  Sales/Marketing;Trading;Understand human behav...
# 4                                         Technology
#
#                                               Skills  \
# 0                                    Python;SQL;Java
# 1  Critical Thinking, Analytic Thinking, SQL, Pro...
# 2             People management;Communication skills
# 3                Accounting Skills;Critical Thinking
# 4  \nPLC Allen Bradley;PLC Ladder Logic;LabVIEW;B...
#
#   Average CGPA or Percentage obtained in under graduation  \
# 0                                                 85
# 1                                               66.5
# 2                                               64.6
# 3                                             75.525
# 4                                              70.68
#
#                   Certificate course title Work in the past  \
# 0                                Linux,Git              Yes
# 1                 Microsoft certification               Yes
# 2                    Resilience psychology               No
# 3                                       No              Yes
# 4  Extreme Productivity (Blinkist Summary)              Yes
#
#   First Job title in your current field of work   \
# 0                                       Software
# 1                     Computer Software Engineer
# 2                                            NaN
# 3                          Relationships manager
# 4                 Plant Instrumentation Engineer
#
#                             title job  Match Percentage
# 0  Software Developer (Female Leader)                58
# 1                       IT Specialist                57
# 2               Clinical Psychologist                70
# 3                Marketing Strategist               100
# 4                       IT Specialist                91

# %%
df.isna().sum()
# Out:
# Name                                                          0
# Gender                                                        0
# Course in UG                                                  0
#  UG specialization? Major Subject (Eg; Mathematics)           0
# Interests                                                     0
# Skills                                                       21
# Average CGPA or Percentage obtained in under graduation       0
# Certificate course title                                     18
# Work in the past                                              0
# First Job title in your current field of work              4877
# title job                                                     0
# Match Percentage                                              0
# dtype: int64

# %%
df['Skills'].unique()
# Out:
# array(['Python;SQL;Java',
#        'Critical Thinking, Analytic Thinking, SQL, Programming, Work under Pressure, Logical Skills, Problem Solving skills',
#        'People management;Communication skills', ...,
#        'SQL, Problem Solving skills',
#        'Programming Language skills;Critical Thinking;Analytical Skills;Editing;Data Visualization skills( Power Bi/ Tableau );SQL',
#        'AI, Java, SQL, C++, R, Linux'], dtype=object)

# %%
# Replace this with your full job title list
job_titles = [
    'Python;SQL;Java',
       'Critical Thinking, Analytic Thinking, SQL, Programming, Work under Pressure, Logical Skills, Problem Solving skills',
       'People management;Communication skills', ...,
       'SQL, Problem Solving skills',
       'Programming Language skills;Critical Thinking;Analytical Skills;Editing;Data Visualization skills( Power Bi/ Tableau );SQL',
       'AI, Java, SQL, C++, R, Linux'
]
mode_value = df['Skills'].dropna().mode()[0]
df['Skills'].fillna(mode_value, inplace=True)

# %%
df = df.rename(columns={'First Job title in your current field of work ': 'First Job in the field'})

# %%
df.columns
# Out:
# Index(['Name', 'Gender', 'Course in UG',
#        ' UG specialization? Major Subject (Eg; Mathematics)', 'Interests',
#        'Skills', 'Average CGPA or Percentage obtained in under graduation',
#        'Certificate course title', 'Work in the past',
#        'First Job in the field', 'title job', 'Match Percentage'],
#       dtype='object')

# %%
mode_value = df['Certificate course title'].dropna().mode()[0]
df['Certificate course title'].fillna(mode_value, inplace=True)

# %%
df.isna().sum()
# Out:
# Name                                                          0
# Gender                                                        0
# Course in UG                                                  0
#  UG specialization? Major Subject (Eg; Mathematics)           0
# Interests                                                     0
# Skills                                                        0
# Average CGPA or Percentage obtained in under graduation       0
# Certificate course title                                      0
# Work in the past                                              0
# First Job in the field                                     4877
# title job                                                     0
# Match Percentage                                              0
# dtype: int64

# %%
df['First Job in the field'].unique()
# Out:
# array(['Software', 'Computer Software Engineer', nan,
#        'Relationships manager', 'Plant Instrumentation Engineer',
#        'Network analyst', 'Student (Unemployed)',
#        'Software Engineer Trainee', 'senior software engineer',
#        'Tele-caller', 'Data Engineer', 'Worked in Research Institute ',
#        'Teacher', 'Embedded System Engineer', 'Assistant Professor',
#        'Mine Engineer', 'Mechanical Design Engineer', 'Finance Manager',
#        'Teaching', 'National Head ', 'Field Engineer',
#        'Investment Banking Associate', 'Sales Executive',
#        'VLSI Digital Design', 'Production manager', 'Software Developer',
#        'Life insurance', 'Developer', 'Full stack developer ',
#        'Process analyst', 'Housewife', 'Junior interior designer ', 'HR',
#        'Pc', 'Design engineer', 'DevOps Engineer', 'Software developer',
#        'Production Engineer', 'Software engineer 1', 'Sales manager',
#        'Junior Software Engineer ', 'Mapping\xa0',
#        'Functional Consultant ', 'Associate SCM ', 'Engineer',
#        'Company Secretary', 'Programmer Analyst Trainee (PAT)',
#        'Programmer', 'Risk analyst\xa0', 'Data Entry',
#        'Associate software engineer', 'Data Scientist-Intern',
#        'Data Analyst ', 'Regional Sales Manager', 'Product Manager',
#        'Engineer-Power Electronics', 'Publishing executive',
#        'Senior software engineer', 'Techno commercial', 'Advocate ',
#        'Electrician', 'Project Manager', 'Mechanical design engineer ',
#        'System Engineer', 'Mechanical Engineer', 'CS',
#        'Associate Software Engineer', 'Software Engineer',
#        'Operation & Maintenance Engineer ', 'Financial Analyst',
#        'Research Associate', 'Data Analyst', 'Trainee Developer',
#        'Business Analyst', 'Sr. Territory sales manager\xa0',
#        'Full Stack Developer', 'Lawyer-Forensic Investigations',
#        'Assistent Manger', 'litigation', 'Civil & Structural Engineer',
#        'Scientist', 'Business', 'Software Engineer ', 'Supply Chain',
#        'Associate IT consultant', 'Buliding management system ',
#        'Sales force ', 'Deputy warden', 'Web Developer',
#        'Business Consultant\xa0', 'Teaching experience 5 years',
#        'Asst. Manager ', 'Medical Practitioner', 'Sub Editor',
#        '\nResearch Associate', 'Se', 'Sub-editor',
#        'Maths Content Developer ', 'HR executive', 'Civil engineer',
#        'Mahindra and Mahindra financial services limited', 'R&D Engineer',
#        'Associate Consultant', 'Junior programmer', 'Vfx artist',
#        'logical trainee associate', 'PLM CONSULTANT\xa0',
#        'Quality Engineer', 'Design engineer ', 'UX designer ',
#        'Swimming coach', 'Office assistant and acoounts',
#        'Software Programmer', 'Assistant System Engineer ',
#        'Back-end Developer ', 'Maintenance Engineer-Mechanical',
#        'Planning manager', 'Operator', 'Associate consultant',
#        'Associate technology l2', 'Lab assistent', 'Test engineer',
#        'Marketing Manager', 'Data Scientist ',
#        'Graduate Quality Engineer', 'ERP IMPLEMENTATION',
#        'Junior system engineer trainee', 'Customer operation associate',
#        'Structural engineer', 'Design Engineer', 'QA Analyst ',
#        'Data entry', 'Sales ', 'Devops Engineer', 'Key Account Manager',
#        'Trainee', 'Java Developer', 'Assistant System Engineer (TCS)',
#        'Sr. Executive in Data Management. ', 'Automation in java lang',
#        'Back End Developer', 'Mobile Application Developer', 'Doctor',
#        'Service Advisor ', 'Asst finance manager',
#        'Digital/Social Media Marketer', 'CIS ', '\nProgrammer Analyst',
#        'Assistant system engineer trainee', 'Operations Management\xa0',
#        'SQL Developer', 'Front End Developer', 'Software engineer',
#        'Listing, Marketting , Stocking and Selling', 'AWS Architect',
#        'Articleship\xa0', 'Dental surgeon ',
#        'Hardware PCB Design Engineer', 'Production field',
#        'Production Supervisor ', '\nCyber Security Analyst',
#        'Account Assistant\xa0', 'Python instructor', 'Crime reporter ',
#        'Stock Trader', 'Software Developer Executive',
#        'graduatee engineer', 'Senior assistant delivery coordinator ',
#        'Programmer ', 'Modeler ', 'BA', 'Investment Banking Analyst',
#        'Journalist ', 'Junior sub editor', 'Content Creator',
#        'Project Coordinator', 'DET', 'Mechanical Supervisor ',
#        'Quality Engineer ', 'Test Analyst', 'Senior PMO - Data Analyst',
#        'Design Engineer ', 'Site engineer', 'Developer ', 'Store keeper',
#        'Sales', 'Associate consultant ',
#        'Instrumentation and Control Engineer ',
#        'Java Full Stack Developer', 'Chemist in pharmaceutical',
#        'Business developer', 'Chartered Accountant',
#        'Web Developer and Digital Marketer', 'Sub-editor ',
#        'Customer service ', 'Catalog Associate', 'Managing director\xa0',
#        'Mechanical design Engineer',
#        'Video labeling(Artificial intelligence) and Medical Coding',
#        'Admin', 'Senior Analyst', 'Quality Assurance ',
#        'Business development associate', 'Statistical programmer',
#        'Analyst ', 'Lotus Notes Admin',
#        'Senior Technical Recruiter, Recruitment Specialist, Talent Acquisition Specialist (IT)',
#        'Structural Engineer', 'digital marketing reqruiter',
#        'Linux Administrator', 'Analyst\xa0', 'store assistant',
#        'Executive Engineer ', 'Network engineer',
#        'Product development associate', 'Team lead in Mortgage banking;',
#        'Dot net Developer', 'Receptionist in coaching center', 'Dancing ',
#        'Research Fellow', 'Not working\xa0', 'Assistent Engineer',
#        'ML Engineer', 'Associate Professional\xa0',
#        'Electronics  Engineer- Research Analyst', 'MIS Executive\xa0',
#        'graduate trainee', 'HDFC BANK ',
#        '\nLab Technician -Food Safety & Quality', 'Legal Associate ',
#        'Power',
#        'Still working jbm auto pvt Ltd company Engineering quality department',
#        'Request Proposal Manager', 'Business Development Manager',
#        'Traniee', 'Associate Engineer - Controls & Software',
#        'SAFETY OFFICER', 'Data scientist', 'DATA ANALYST',
#        'associate Engineer', 'Sales Service Engineer-Electrical',
#        'Young Horticulture expert', 'Quality engineer ',
#        'Back Office Executive',
#        'Salem Farmers producer company/current job appen ',
#        'HR Executive', 'Clinical Research Associate ', 'Site Engineer',
#        'Accountent', 'BMS executive ', 'Entrepreneur',
#        'Civil Design Engineer', 'Quality control engineer ',
#        'Cyber Security Analyst', 'SOFTWARE Tester', 'Design Engineer\xa0',
#        'Product Engineer (AI/ML)',
#        'Mahendra Next Wealth IT Pvt Ltd.Malasamuthiram', 'Sale executive',
#        'Embedded Developer', 'Project Engineer ', 'Journalist',
#        'Desktop support engineer', 'Software tester', 'VFX Designer',
#        'Hr admin', 'Medical representative ', 'Back end operations',
#        'Store manager ', 'Associate', 'Law Intern', 'Process exceutive ',
#        'Mechine Learning Engineer', 'Self employed', 'Cultfit',
#        'Engineer ', 'Project intern', 'Marketing Executive',
#        'Clothes designer', 'Marketing executive\xa0',
#        'I m a marketing head', 'software developer', 'Motor controller',
#        'Saleforce developer', 'Billing engineer ', 'Service advisor',
#        'Telecaller', 'iOS Developer', 'accountant ', 'Data Scientist',
#        'Material Planner', 'Front End Java Developer',
#        'Field sales officer', ' CES-CAE- FEA Analyst',
#        ' Database Administrator', 'associate trainee',
#        'trainee and associates', 'Production specialist',
#        'Software Developer ', 'Mechanical product developer ',
#        'General masdor', 'Analyst', 'Senior associate',
#        'Compliance Engineer', 'Mechanical Engineer ', 'ASP.NET Developer',
#        'Process executive-Data', 'Active Trading Service',
#        'Computerized accounting', 'Loco pilot', 'Dietician',
#        'ASSOCIATE OPERATIONS PROCESSOR-1', 'Sr. Political Analyst ',
#        'Buisness devlopment excutive', 'Operations specialist',
#        'Tata projects ltd ', 'Testing engineer ',
#        'Associate System Engineer', 'VLSI Developer', 'Graphic Designer',
#        'senior chemist ', 'Quality analyst ',
#        'Dance teacher in Dehli public school Jankipuram Lucknow ', 'ASE',
#        'Teaching Assistant-Biotechnology', 'AWS Developer',
#        'Litigation Lawyer', 'Front End Developer ', 'Civil Engineer',
#        'Executive', 'Team leader', 'Application developer',
#        'Flipkart customer care executive ', 'Maintenance engineer',
#        'Maintenance Engineer-Electrical', 'Content creator',
#        'System Administrator', 'Ast.purchase manager', ' Project Manager',
#        'IT Operations', 'Application Development Analyst',
#        'Site Civil Engineer', 'School accountant ', 'Dance teacher',
#        'PLM Engineer', 'Technical Recruiter', 'site Engineer',
#        'Data analyst', 'Associate Engineer - DevOps',
#        'Data Science and Game Design Trainer',
#        'I was working as Dean R n D', 'ZIGNA AI PVT LTD',
#        'Corporate and Disputes Lawyer', 'Quality Assurances Engineer',
#        'CES-CAE- FEA Analyst', 'Qualitative Analyst',
#        'Process Operations Engineer', 'Tax Consultant', 'TRI',
#        'Sub editor', 'Junior Architect', 'Assistant Professor ',
#        'Traning and Development', 'Real e-state agent', 'IT SUPPORT',
#        'Associative staff', 'Digital marketing executive',
#        'Tax consultant ', 'Fruit business', 'Senior Associate ',
#        'Program engineering (IT)', 'Apprentice DP world Navi Mumbai',
#        'Technical writer\xa0', 'Junior Developer',
#        '\nSpecialist Programmer', 'Information Secuirty Analyst',
#        'Data analysis', 'Jr. Engineer', 'Lecturer',
#        '\nHardware Design Engineer', 'Web developer',
#        'Finance consultant', 'Medical Posting', 'System engineer',
#        'Intern at innodatatics', 'supervisor',
#        'Transcriber/Script editor', 'Felix healtcare pvt ltd',
#        'Operation Manager', 'Trainee consultant - Quality ',
#        'Lawyer -IPR', 'Medical and sales reprasentative', 'Teaching job',
#        'Associate it consultant - erp', 'Intern',
#        'GAT- Engine testing engineer', 'sub Engineer', 'Telemarketer',
#        'DevOps Engineer ', 'Data entry operator\xa0', 'Senior Editor',
#        'BUSINESS DEVELOPMENT MANAGER', 'Project Associate',
#        'Technical Associate ', 'Business\xa0', 'Tech support\xa0',
#        'Researcher', 'Content writer and creative strategist',
#        'IT Engineer', 'Software testing', 'Programmer analyst',
#        'QA Analyst', 'Entry Level Software Engineer', 'PAT',
#        'SAP consultant', 'FSC', 'Customer care', 'Psychologist',
#        'FITNESS CONSULTANT EXPERT\xa0', 'Copywriter ',
#        'Software engineer\xa0', 'Accountant', '\nBiocurator', 'nothing',
#        'TESTING ENGINEER', 'Pharma Benefit Analyst ',
#        'Cyber Security Engineer', 'Associate Data Scientist',
#        'Security officer ', 'Business Trainee', 'Python Developer',
#        'Operations specialist ', 'Talent Acquisition Executive',
#        'Management trainee ', 'Human Resources Assistant',
#        'Procurement engineer', 'GET ', 'Telecaller,sale exicutive',
#        'Operations Engineer', 'Software engineer ', 'Purchase executive',
#        'QA Specialist', 'Software Tester', 'Hardware Engineer',
#        'APAC Engineer', 'Associate Engineer', 'Personal Advisory',
#        'RPA developer', 'Relationship manager at icici',
#        'Business operations', 'Sales excellent', 'Machine operator\xa0',
#        'Gis engineer', 'Retail manager',
#        ' student Onboarding team member ', 'Site engineer ',
#        'Chemical Process Engineer', 'Marketing guy (TMA) ',
#        'Systems engineer ', 'Social media executive', 'Salesforce Admin',
#        'UPS supervisor', 'Software Development Engineer',
#        'Jumio Document Verification Team', 'manager', 'Placement Trainee',
#        'Php developer', 'Game Programmer', 'QC engineer',
#        'Miritary soldier ', 'Assistant Engineer ', 'Graphics Designer ',
#        'Scientist in Downstream Protein Purification',
#        'Associate System Engineer ', 'Gatemen', 'NA ',
#        'PREVIOUSLY WORKED', 'Cloud Engineer',
#        'ASSISTANT SYSTEM ENGINEER TRAINEE', 'Product Specialist', 'MIS',
#        'Nothing', 'Hr Assistant II', 'VFX Production Assistant'],
#       dtype=object)

# %%
mode_value = df['First Job in the field'].dropna().mode()[0]
df['First Job in the field'].fillna(mode_value, inplace=True)

# %%
df.isna().sum()
# Out:
# Name                                                       0
# Gender                                                     0
# Course in UG                                               0
#  UG specialization? Major Subject (Eg; Mathematics)        0
# Interests                                                  0
# Skills                                                     0
# Average CGPA or Percentage obtained in under graduation    0
# Certificate course title                                   0
# Work in the past                                           0
# First Job in the field                                     0
# title job                                                  0
# Match Percentage                                           0
# dtype: int64

# %%
df.head()
# Out:
#                Name  Gender Course in UG  \
# 0       A.Uha Priya  Female         B.Sc
# 1             Aadil    Male          B.E
# 2           Aakriti  Female           BA
# 3    Aanchal sharma  Female          MBA
# 4  Aangkeeta Sarkar  Female       B.Tech
#
#    UG specialization? Major Subject (Eg; Mathematics)  \
# 0                              Computer Applications
# 1                       Computer Science Engineering
# 2                                         Psychology
# 3                                           Commerce
# 4                        Instrumentation Engineering
#
#                                            Interests  \
# 0                                    Cloud computing
# 1                                         Technology
# 2                         Understand human behaviour
# 3  Sales/Marketing;Trading;Understand human behav...
# 4                                         Technology
#
#                                               Skills  \
# 0                                    Python;SQL;Java
# 1  Critical Thinking, Analytic Thinking, SQL, Pro...
# 2             People management;Communication skills
# 3                Accounting Skills;Critical Thinking
# 4  \nPLC Allen Bradley;PLC Ladder Logic;LabVIEW;B...
#
#   Average CGPA or Percentage obtained in under graduation  \
# 0                                                 85
# 1                                               66.5
# 2                                               64.6
# 3                                             75.525
# 4                                              70.68
#
#                   Certificate course title Work in the past  \
# 0                                Linux,Git              Yes
# 1                 Microsoft certification               Yes
# 2                    Resilience psychology               No
# 3                                       No              Yes
# 4  Extreme Productivity (Blinkist Summary)              Yes
#
#            First Job in the field                           title job  \
# 0                        Software  Software Developer (Female Leader)
# 1      Computer Software Engineer                       IT Specialist
# 2            Student (Unemployed)               Clinical Psychologist
# 3           Relationships manager                Marketing Strategist
# 4  Plant Instrumentation Engineer                       IT Specialist
#
#    Match Percentage
# 0                58
# 1                57
# 2                70
# 3               100
# 4                91

# %%
# --- 1. Data Preparation ---
num_additional_rows = 160
if df.shape[0] < num_additional_rows + 10:
    for _ in range(num_additional_rows):
        base_row_index = np.random.randint(0, len(df['Name']))
        df_row = {k: df[k][base_row_index] if isinstance(df[k], list) else df[k] for k in df.keys()}

        # Enhanced randomization
        df_row['Average CGPA or Percentage obtained in under graduation'] = np.random.uniform(6.0, 9.9)
        
        for text_col in ['Interests', 'Skills', 'Work in the past']:
            if np.random.rand() < 0.1:
                df_row[text_col] = np.nan
            else:
                if isinstance(df[text_col], list):
                    df_row[text_col] = np.random.choice([x for x in df[text_col] if pd.notna(x)])
        
        df = pd.concat([df, pd.DataFrame([df_row])], ignore_index=True)

print(f"DataFrame size: {df.shape[0]} rows")

# --- 2. Feature Engineering ---
target_column_name = 'title job'

try:
    X = df.drop(columns=[target_column_name, 'Name'], errors='ignore').copy()  # Remove potential leaky features
    y = df[target_column_name]
except KeyError as e:
    print(f"\nError: {str(e)}")
    print("Available columns:", df.columns.tolist())
    raise

# Verify target distribution
print("\nTarget class distribution:")
print(y.value_counts(normalize=True))

# --- 3. Feature Definitions ---
categorical_features = ['Gender', 'Course in UG', ' UG specialization? Major Subject (Eg; Mathematics)', 
                       'Certificate course title']
numerical_features = ['Average CGPA or Percentage obtained in under graduation']
text_features = ['Interests', 'Skills', 'Work in the past']

# Validate features
missing_features = [f for f in categorical_features + numerical_features + text_features if f not in X.columns]
if missing_features:
    raise ValueError(f"Missing features: {missing_features}")

# --- 4. Preprocessing Pipeline ---
def combine_text_columns(df_input):
    combined = df_input[text_features].fillna('').astype(str).apply(' '.join, axis=1)
    return combined.str.strip()

text_transformer = Pipeline([
    ('combiner', FunctionTransformer(combine_text_columns, validate=False)),
    ('tfidf', TfidfVectorizer(max_features=500, stop_words='english', ngram_range=(1, 2)))
])

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_features),
    ('num', Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]), numerical_features),
    ('text', text_transformer, text_features)
], remainder='drop')

# --- 5. Model Pipeline with Enhanced Settings ---
# Calculate class weights dynamically
classes = np.unique(y)
weights = compute_class_weight('balanced', classes=classes, y=y)
class_weights = dict(zip(classes, weights))

model_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(
        n_estimators=100,
        max_depth=5,  # Reduced to prevent overfitting
        min_samples_split=5,
        class_weight=class_weights,
        random_state=42
    ))
])

# --- 6. Evaluation ---
# Cross-validation first
print("\nRunning cross-validation...")
cv_scores = cross_val_score(model_pipeline, X, y, cv=5, scoring='accuracy')
print(f"CV Accuracy: {np.mean(cv_scores):.4f} (±{np.std(cv_scores):.4f})")

# Train-test split evaluation
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y)

print("\nTraining model...")
model_pipeline.fit(X_train, y_train)

print("\n--- Evaluation Metrics ---")
y_pred = model_pipeline.predict(X_test)

# Comprehensive metrics
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# DataFrame size: 20000 rows
#
# Target class distribution:
# title job
# IT Specialist                         0.26990
# General Specialist                    0.23150
# Software Developer                    0.17525
# Software Developer (Female Leader)    0.07520
# Sales Executive                       0.05565
# Public Relations Specialist           0.04780
# Teacher                               0.04475
# Entrepreneur                          0.01715
# Content Writer                        0.01515
# Marketing Strategist                  0.01390
# Business Consultant                   0.01335
# Statistician                          0.01320
# Financial Analyst                     0.00860
# Physicist                             0.00785
# Data Scientist                        0.00445
# Clinical Psychologist                 0.00310
# Instrumentation Engineer              0.00235
# Organizational Psychologist           0.00085
# Name: proportion, dtype: float64
#
# Running cross-validation...
# CV Accuracy: 0.7251 (±0.0279)
#
# Training model...
#
# --- Evaluation Metrics ---
# Accuracy: 0.7497

# %%
import pandas as pd

def predict_job_from_user_input(model_pipeline):
    print("\n=== Job Prediction System ===")
    print("Please enter the following details:\n")
    
    # Collect user input for each feature
    input_data = {}
    
    # Personal Information
    input_data['Gender'] = [input("Gender (Male/Female/Other): ").strip()]
    
    # Education Details
    input_data['Course in UG'] = [input("Undergraduate Course (e.g., B.E, B.Tech, B.Sc): ").strip()]
    input_data[' UG specialization? Major Subject (Eg; Mathematics)'] = [
        input(" UG Specialization (e.g., Computer Science Engineering): ").strip()
    ]
    
    # Certification
    input_data['Certificate course title'] = [
        input("Certificate/Degree (e.g., Microsoft certification): ").strip()
    ]
    
    # Academic Performance
    while True:
        try:
            cgpa = float(input("Average CGPA/Percentage in UG (e.g., 66.5): "))
            input_data['Average CGPA or Percentage obtained in under graduation'] = [cgpa]
            break
        except ValueError:
            print("Please enter a valid number (e.g., 66.5 or 8.5)")
    
    # Skills and Interests
    input_data['Interests'] = [input("Your professional interests (e.g., Technology): ").strip()]
    input_data['Skills'] = [
        input("Your skills (comma separated, e.g., Critical Thinking, SQL): ").strip()
    ]
    
    # Work Experience
    input_data['Work in the past'] = [
        input("Previous work experience (e.g., IT Specialist): ").strip()
    ]
    
    # Convert to DataFrame
    input_df = pd.DataFrame(input_data)
    
    # Make prediction
    try:
        prediction = model_pipeline.predict(input_df)[0]
        probabilities = model_pipeline.predict_proba(input_df)[0]
        
        print("\n=== Prediction Result ===")
        print(f"Predicted Job Title: {prediction}")
        
        print("\nPrediction Probabilities:")
        for job, prob in zip(model_pipeline.classes_, probabilities):
            print(f"{job}: {prob:.2%}")
        
        return prediction
        
    except Exception as e:
        print(f"\nError making prediction: {str(e)}")
        return None

# Example usage (assuming you have a trained model_pipeline)
if __name__ == "__main__":
    # First you need to have your trained model_pipeline
    # model_pipeline = your_trained_model
    
    print("Job Prediction System")
    while True:
        predicted_job = predict_job_from_user_input(model_pipeline)
        
        another = input("\nMake another prediction? (y/n): ").lower()
        if another != 'y':
            print("\nThank you for using the Job Prediction System!")
            break
# Out:
# Job Prediction System
#
# === Job Prediction System ===
# Please enter the following details:
# Gender (Male/Female/Other):  Female
# Undergraduate Course (e.g., B.E, B.Tech, B.Sc):  BA
#  UG Specialization (e.g., Computer Science Engineering):  Psychology
# Certificate/Degree (e.g., Microsoft certification):  Resilience psychology
# Average CGPA/Percentage in UG (e.g., 66.5):  64.6
# Your professional interests (e.g., Technology):  Understand human behaviour
# Your skills (comma separated, e.g., Critical Thinking, SQL):  People management;Communication skills
# Previous work experience (e.g., IT Specialist):  nO
# === Prediction Result ===
# Predicted Job Title: Clinical Psychologist
#
# Prediction Probabilities:
# Business Consultant: 3.22%
# Clinical Psychologist: 54.75%
# Content Writer: 2.87%
# Data Scientist: 1.70%
# Entrepreneur: 2.74%
# Financial Analyst: 2.48%
# General Specialist: 3.59%
# IT Specialist: 2.92%
# Instrumentation Engineer: 1.94%
# Marketing Strategist: 2.42%
# Organizational Psychologist: 0.00%
# Physicist: 2.93%
# Public Relations Specialist: 4.05%
# Sales Executive: 2.79%
# Software Developer: 2.09%
# Software Developer (Female Leader): 2.67%
# Statistician: 3.33%
# Teacher: 3.52%
# Make another prediction? (y/n):  N
# Thank you for using the Job Prediction System!
